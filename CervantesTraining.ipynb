# %%
import requests
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from bs4 import BeautifulSoup
from dateutil.parser import parse
import re
import nltk
import pycrfsuite

# %%
# read in manually parsed data for training
cervParse = pd.read_csv(r'C:\Users\jschlajo\Desktop\cervantesParses.csv', encoding='latin-1')

# %%
# in this example I would want 'Brightside, Dorfex Bos, GrymeTyme, Jordan Polovina' as artists
# many exmaples I made up based on common trends, so I could train the model accordingly due to a lack of data
cervParse['EventTitle'][0]
# Out:
# 'Re:Search Feat. Brightside and Dorfex Bos w/ GrymeTyme  ( Late Set )  ,  Jordan Polovina'

# %%
cervParse.head()
# Out:
#                                           EventTitle  \
# 0  Re:Search Feat. Brightside and Dorfex Bos w/ G...
# 1  Re:Search Feat. Ablaze and Clinton Sly w/ Hero...
# 2  Re:Search Feat. Adventure Club and Smokestax w...
# 3  Re:Search Feat. Kursa and Fuski w/ Drakk (Late...
# 4  Magnolia North feat. Steve Foltz of Trout Stea...
#
#                                         manualParses
# 0  Brightside, Dorfex Bos, GrymeTyme, Jordan Polo...
# 1              Ablaze, Clinton Sly, Herobust, Zempra
# 2           Adventure Club, Smokestax, Purge, Dyatic
# 3         Kursa, Fuski, Drakk, Robotic Pirate Monkey
# 4  Magnolia North, Steve Foltz, Liver Down The River

# %%
# pad comma's with spaces so the comma and word are recognized as different tokens (and parentheses)
cervParse['EventTitle'] = cervParse['EventTitle'].map(lambda x : ' , '.join(x.split(',')))
cervParse['EventTitle'] = cervParse['EventTitle'].map(lambda x : ' ( '.join(x.split('(')))
cervParse['EventTitle'] = cervParse['EventTitle'].map(lambda x : ' ) '.join(x.split(')')))

# %%
cervParse['manualParses'].fillna('', inplace = True)

# %%
def labelTokens(row):
    tokenSet = []
    for x in row.EventTitle.split():
        if x in [',']:
            value = (x, 'S')
            tokenSet.append(value)
        # split on every space to tokenize every word or character in the event name
        elif x in row.manualParses:
            # if the word is in Parsed, label it as an artist
            value = (x, 'A')
            tokenSet.append(value)
            
        elif x in ['and','w/','/W','+','b2b','x','with']:
            # and, w/ and commas are commonly used as seperators, label these S = 'Seperators' (& and typically is part of an artist name)
            value = (x, 'S')
            tokenSet.append(value)
        else:
            # otherwise, it is 'Irrelevant'
            value = (x,'I')
            tokenSet.append(value)
    return tokenSet

# %%
cervParse['labeled'] = cervParse.apply(labelTokens, axis=1)

# %%
cervParse['labeled'][19]
# Out:
# [('RE:Search', 'I'),
#  ('Feat.', 'I'),
#  ('Homemade', 'A'),
#  ('Spaceship', 'A'),
#  ('w/', 'S'),
#  ('Special', 'I'),
#  ('Guest', 'I'),
#  ('Pigeon', 'I'),
#  ('Hole', 'A'),
#  (',', 'S'),
#  ('Kyral', 'A'),
#  ('x', 'A'),
#  ('Banko', 'A'),
#  ('(', 'I'),
#  ('Late', 'I'),
#  ('Set', 'I'),
#  (')', 'I'),
#  (',', 'S'),
#  ('Jordan', 'A'),
#  ('Polovina', 'A')]

# %%
def POStags(labels):
    data = []
    tokens = [t for t, labeled in labels]
    # for every token in the event title, tag with a Part Of Speach label from the NLTK library
    tagged = nltk.pos_tag(tokens)
    data.append([(w, pos, label) for (w, label), (word, pos) in zip(labels,tagged)])
    
    return data

# %%
cervParse['POS'] = cervParse['labeled'].map(POStags)
cervParse['POS'] = cervParse['POS'].map(lambda x : x[0])

# %%
cervParse['POS'][0]
# Out:
# [('Re:Search', 'NNP', 'I'),
#  ('Feat.', 'NNP', 'I'),
#  ('Brightside', 'NNP', 'A'),
#  ('and', 'CC', 'S'),
#  ('Dorfex', 'NNP', 'A'),
#  ('Bos', 'NNP', 'A'),
#  ('w/', 'NN', 'S'),
#  ('GrymeTyme', 'NNP', 'A'),
#  ('(', '(', 'I'),
#  ('Late', 'NNP', 'I'),
#  ('Set', 'NNP', 'I'),
#  (')', ')', 'I'),
#  (',', ',', 'S'),
#  ('Jordan', 'NNP', 'A'),
#  ('Polovina', 'NNP', 'A')]

# %%
# pos data into a list to create features from
data = cervParse['POS'].tolist()

# %%
def word2features(doc, i):
    
    # create features for training based on charchteristics of the word, and its surrounding words/ charachters
    
    word = doc[i][0]
    postag = doc[i][1]
    features = [
        'word.lower=' + word.lower(),
        'bias',
        'postag=' + postag,
        'word.isupper=%s' % word.isupper(),
        'word.istitle=%s' % word.istitle()
    ]
    
    if i > 0:
        word1 = doc[i-1][0]
        postag1 = doc[i-1][1]
        features.extend([
            '-1:word.lower=' + word1.lower(),
            '-1:postag=' + postag1,
            '-1:postag[:2]=' + postag1[:2],
            '-1:word.istitle=%s' % word1.istitle(),
            '-1:word.isupper=%s' % word1.isupper()
            
        ])
        
    else:
        features.append('BOS')
        
    if i < len(doc)-1:
        word1 = doc[i+1][0]
        postag1 = doc[i+1][1]
        features.extend([
            '+1:word.lower=' + word1.lower(),
            '+1:postag=' + postag1,
            '+1:postag[:2]=' + postag1[:2],
            '+1:word.istitle=%s' % word1.istitle(),
            '+1:word.isupper=%s' % word1.isupper()
        ])
    else:
        features.append('EOS')
                
    return features

# %%
from sklearn.model_selection import train_test_split

# A function for extracting features in documents
def extract_features(doc):
    return [word2features(doc, i) for i in range(len(doc))]

# A function fo generating the list of labels for each document
def get_labels(doc):
    return [label for (token, postag, label) in doc]

X = [extract_features(doc) for doc in data]
y = [get_labels(doc) for doc in data]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
import pycrfsuite
trainer = pycrfsuite.Trainer(verbose=True)

# Submit training data to the trainer
for xseq, yseq in zip(X_train, y_train):
    trainer.append(xseq, yseq)

# Set the parameters of the model
trainer.set_params({
    # coefficient for L1 penalty
    'c1': 0.1,

    # coefficient for L2 penalty
    'c2': 0.01,  

    # maximum number of iterations
    'max_iterations': 200,

    # whether to include transitions that
    # are possible, but not observed
    'feature.possible_transitions': True
})

# Provide a file name as a parameter to the train function, such that
# the model will be saved to the file when training is finished
trainer.train('crf.model')

# %%
tagger = pycrfsuite.Tagger()
tagger.open('crf.model')
y_pred = [tagger.tag(xseq) for xseq in X_test]

# Let's take a look at a random sample in the testing set

for i in range(0,2):
    print('-----')
    for x, y in zip(y_pred[i], [x[0].split("=")[1] for x in X_test[i]]):
        print("%s (%s)" % (y, x))
# Out:
# -----
# fire (A)
# & (A)
# ice (A)
# w/ (S)
# johns (A)
# band (A)
# , (S)
# the (A)
# cattle (A)
# ( (I)
# uk (I)
# ) (I)
# -----
# re:search (I)
# feat. (I)
# lord (A)
# swan (A)
# ( (I)
# blanke (A)
# x (S)
# louis (A)
# futon (A)
# x (S)
# eprom (A)
# ) (I)
# w/ (S)
# vanic (A)
# , (S)
# audiowrx (A)
# and (S)
# special (I)
# guests (I)

# %%
cervParse['features'] = cervParse['POS'].map(lambda x : extract_features(x))
# extract features for every event title

# %%
cervParse['preds'] = cervParse.features.map(lambda x : [tagger.tag(x)])
# map trained model the features of each event title
cervParse['toks'] = cervParse.POS.map(lambda x: [x[0] for x in x])
# get prediction tags and word tokens into lists so they can be combined

# %%
def zipper(row):
    return [(x,y) for x,y in list(zip(row.toks, row.preds[0])) if y in ['A','S']]

# %%
cervParse['artistPreds'] = cervParse.apply(zipper, axis=1)

# %%
def combine(row):
    results = [(x,y) for x,y in list(zip(row.toks, row.preds[0]))]
    artist = []
    for x in results:
        if x[1] == 'A':
            artist.append(x[0])
        else:
            artist.append(',')
    return ', '.join([y for y in [x.strip() for x in ' '.join(artist).split(',')] if y != ''])

# %%
cervParse['predictions'] = cervParse.apply(combine, axis=1)

# %%
pd.options.display.max_colwidth = 1000

# %%
cervParse[['EventTitle','predictions']]
# Out:
#                                                                                                                                                                                                                                                                                         EventTitle  \
# 0                                                                                                                                                                                                         Re:Search Feat. Brightside and Dorfex Bos w/ GrymeTyme  ( Late Set )  ,  Jordan Polovina
# 1                                                                                                                                                                                                                      Re:Search Feat. Ablaze and Clinton Sly w/ Herobust  ( Late Set )  ,  Zempra
# 2                                                                                                                                                                                                                   Re:Search Feat. Adventure Club and Smokestax w/ Purge  ( Late Set )  ,  Dyatic
# 3                                                                                                                                                                                                                 Re:Search Feat. Kursa and Fuski w/ Drakk  ( Late Set )  ,  Robotic Pirate Monkey
# 4                                                                  Magnolia North feat. Steve Foltz of Trout Steak Revival and Special Guest Grace Clark w/ Liver Down The River  ( Late Set )  ,  Thunder and Rain  ( Patio Set )  ,  Jacob Moss & Matt Flaherty of Part & Parcel  ( Patio Set )
# 5                                                               Wookiefoot and Mike Love w/ Yak Attack ,  Analog Son ,  A-Mac & The Height ,  Graham Good & The Painters ,  On the PATIO: Pick & Howl ,  Modern Whiskey Market - Silent Disco: Dozier ,  Oomah  ( of Evanoff )  ,  Tropical Waffle
# 6                                                                                                                                                                                                                                         Neetesh Jung Kunwar & Bartika Eam Rai with Jaanvi Gurung
# 7                                           Porter Neville Quartet feat. George Porter Jr  ( The Meters )  ,  Ivan Neville  ( Dumpstaphunk )  ,  Ian Neville  ( Dumpstaphunk )  ,  Terrence Houston  ( The Funky Meters )  w/ JoeBaby All-Star Jam ft. Jermal Watson  ( Dirty Dozen )  ,  and More
# 8                                                                                       Maydaze Music Fest ft. Stay Gypsy ,  Adamsite ,  Paradox ,  Feens! ,  Nothing's Permanent ,  Ain't From Here ,  Sunny Sideways ,  The Cereal Company ,  Stereo Indica Cinema ,  Messenger Music Collective
# 9                                                                                                                                                                                                                                                         The Elovaters w/ CollieRAD ,  MountainUs
# 10          The Funk Sessions ft. Isaac Teel  ( TAUK )  w/ Marc Brownstein  ( The Disco Biscuits )  ,  Jennifer Hartswick  ( TAB )  ,  Nick Cassarino  ( The Nth Power )  ,  Joey Porter  ( The Motet )  ,  Nicholas Gerlach  ( Michal Menert & The Pretty Fantastics )  + D-Vibes Watermelon Funk
# 11                                                                                                                                                                                Re:Search Feat. Dynohunter w/ Casual Commander  ( Sunsquabi )  ,  Aaron Bordas  ( Late Set )  ,  Jordan Polovina
# 12                                    Bloodkin w/ Daniella Katzir Band  ( ft. Gabe Mervine ,  Brian McRae of Kyle Hollingsworth Band ,  Mike Tallman ,  Austin Zalatel of Euforquestra )  ,  Big Time Rascals  ( 2 sets on the Patio: 1 Original & 1 Pickin' On Nirvana )  ,  The Moves Collective
# 13                                                                                                                                                                                                                                                Upstate w/ Emma Mayes & The Hip ,  Plain Faraday
# 14                                                                                                                                                                                             Xavier Wulf - The HollowSquad Tour w/ Beau Young Prince ,  Marty Grimes ,  Reco Havoc ,  Indigo Ace
# 15                                                                                                                                                                                                                Morphics - The Dankness Tour w/ Dirty Audio ,  Tokey ,  Reco Havoc ,  Indigo Ace
# 16                             A Tribute to Allman Brothers Band by The Family Peach ft. Vaylor Trucks ,  Melody Trucks ,  Jeff Franca  ( Thievery Corp. )  ,  Todd Smallie  ( JJ Grey & Mofro )  ,  James Dumm ,  Bill McKay ,  Eric Sanders w/ Coral Creek   ( A Tribute to The Grateful Dead )
# 17   Afton Showcase w/ Anomalous ,  Truth ,  Doc Suess & Lakhryth ,  Sensei3Moons ,  Nuclear Ninja ,  Bby Backwood ,  BMW Records BB ,  TRiP ,  JR Tycoon  ,  Talisa ,  Buggabearmaxie ,  Hiatus W/ Special Guest Atlus ,  KINGPEN KEN ,  187 klaN ,  Getti ,  Gadgio ,  Fuego James ,  and Guests
# 18  Denver Showcase w/ Anomalous ,  Truth ,  Doc Suess & Lakhryth ,  Sensei3Moons ,  Nuclear Ninja ,  Bby Backwood ,  BMW Records BB ,  TRiP ,  JR Tycoon  ,  Talisa ,  Buggabearmaxie ,  Hiatus W/ Special Guest Atlus ,  KINGPEN KEN ,  187 klaN ,  Getti ,  Gadgio ,  Fuego James ,  and Guests
# 19                                                                                                                                                                              RE:Search Feat. Homemade Spaceship w/ Special Guest Pigeon Hole ,  Kyral x Banko  ( Late Set )  ,  Jordan Polovina
# 20                                                                                                                                                                                               RE:Search Feat. iLL Gates w/ Special Guest Ghostz ,  Riot x Ten  ( Late Set )  ,  Jordan Polovina
# 21                                                                                                                                                                                                      RE:Search Feat. Holly w/ Special Guest Space Laces ,  Kill x Will  ( Late Set )  ,  Snacks
# 22                                                                                                                                                                                               RE:Search Feat. Kadaver w/ Special Guest Cookie Monsta ,  Prob x Cause  ( Late Set )  ,  Teminite
# 23                                                                       Coral Creek ft. Special Guests Drew Emmitt  ( Leftover Salmon )  & Todd Sheaffer  ( Railroad Earth )  w/ Todd Sheaffer Solo Set ,  Rum Creek  ( ft. members of Coral Creek and Hot Buttered Rum )  ,  Mary-Elaine Jenkins
# 24                                                                                                                                                                          Hieroglyphics  ( All Original Members )  w/ Rap Noir ,  Stoney Hawk ,  S.A.V.E.1 ,  Mike Wird ,  L0S ,  Stonewall BLVD
# 25                                                                                                                                                                                             Scott Law & Ross James Cosmic Twang ft. Nicki Bluhm ,  Keith Moseley ,  & Alex Koford w/ The Higgs
# 26                                                                                                                                                                                                                Tor w/ Blossomn ,  Andrew Rothschild ,  Moon Frog Band - The Road To Sonic Bloom
# 27                                                                                                                                                                                                                                                                                      NLE Choppa
# 28                                                                                                                                                            Re:Search feat. C.H.A.Y.  ( Dirtybird / Mau5trap )  and Kyle Walker  ( Bite This! / Insomniac )  w/ Andy Immerman ,  Jordan Polovina
# 29                                                                                                                                                 Circus No. 9 and Fireside Collective  ( Patio Set )  w/ Bunch Of Strangers  ( Patio Set )  - Official Brewgrass Music & Beer Festival Pre-Party
# ..                                                                                                                                                                                                                                                                                             ...
# 62                                                                                                                                                                                                         Hymn For Her w/ The Deer ,  Che Apalache  ( Argentina - Patio Set )  and Special Guests
# 63                                                                                                                                                                                                                                                            Lost Dog Street Band w/ Matt Heckler
# 64                                                                                                                                                                                                                                                                  Butcher Brown w/ Dirty Revival
# 65                                                                                                                                                                                                                                                            Dobre Brothers Live  ( Early Show )
# 66                                                                                                                                                                                                                           RE:Search Feat. Defunk w/ Memba ,  Jordan Polovina and Special Guests
# 67                                                                                                                                                           Jay Cobb Anderson Band w/ Nirvana's Unplugged performed by members of Part & Parcel ,  Mama Magnolia ,  Analog Son and Special Guests
# 68                                                                                                                                                                                                                      ARISE Music Festival  ///  AUG 2 - 4  ///  Sunrise Ranch ,  Loveland ,  CO
# 69                                                                                                                                                                                                          Nolatet feat. Mike Dillon ,  Brian Haas ,  and James Singleton  w/ Special Guest Dandu
# 70                                                                                                                                                                                   Re:Search feat. Ultrasloth  ( Duffrey x BioLumigen x kLL sMTH )  w/ 5AM ,  Jordan Polovina and Special Guests
# 71                                                                                                                                                                                                           Re:Search feat. Tristam  ( Griz x Leau x Jason )  w/ Born ,   DMVU and Special Guests
# 72                                                                                                                                                                                            Re:Search feat. Lord Swan  ( Blanke x Louis Futon x Eprom )  w/ Vanic ,  Audiowrx and Special Guests
# 73                                                                                                                                                                                            Re:Search feat. Jampact  ( Major Lazer x Ratchet x Kenno )  w/ 1788 ,  Jason Ross and Special Guests
# 74                                                                                                                                                                                               The Billy Failing Band w/ The Dirty Grass Players  ( Patio Set )  ,  Pierce Edens  ( Patio Set )
# 75                                                                                                                                                                                                                                                       STS9 Wave Spell Live in Belden Town ,  CA
# 76                                                                                                                                                                               40 Oz To Freedom  ( Sublime Tribute )  w/ Lil' Ween  ( Ween Tribute )  Performing "The Mollusk" w/ Special Guests
# 77                                                                                                                                                                                                                                               SuicideGirls: Blackheart Burlesque  ( THURSDAY )
# 78                                                                                                                                                                                                                                                 SuicideGirls: Blackheart Burlesque  ( FRIDAY )
# 79                                                                                                                                                                                                                RE:Search Feat. The Geek x VRV w/ Poldoore ,  Jordan Polovina and Special Guests
# 80                                                                                                                                                                                                                             The New Mastersounds w/ Very Special Guests Ghost-Note  ( FRIDAY )
# 81                                                                                                                                                                                                2-DAY PASS: The New Mastersounds w/ Very Special Guests Ghost-Note  ( Fri 10/11 and Sat 10/12 )
# 82                                                                                                                                                                                            Cycles Presents: The Game Show - An Interactive Concert & Game Show Experience w/ Special Guests TBA
# 83                                                                                                                                                                                                                                        Wu-Tang Clan with Jedi Mind Tricks ,  Immortal Technique
# 84                                                                                                                                                                                                                                                                      An Evening With That 1 Guy
# 85                                                                                                                                                                                                                                                Hilltop Hoods w/ Adrian Eagle and Special Guests
# 86                                                                                                                                                                                                                 Re:Seach feat. Disco  (  Floopy x Drippy x Ants  )  w/ tacos and Special Guests
# 87                                                                                                                                                                                                 Re:Seach feat. Danky  (  Popcorn x Zeds Dead x Louis the Child  )  w/ shrimp and Special Guests
# 88                                                                                                                                                                                                                                                           I Make Music  (  Random Shit Here  )
# 89                                                                                                                                                                                                                                                     Advice With Him w/ The Bike ,  and kLL sMTH
# 90                                                                                                                                                                                                                                                    Fire & Ice w/ Heem Banana and Special Guests
# 91                                                                                                                                                                                                                 Re:Search Feat. Stylust w/ Special Guest Shrimp Taco ,  CharlestheFirst ,  ZLEN
#
#                                                                                                                                                                                              predictions
# 0                                                                                                                                                     Brightside, Dorfex Bos, GrymeTyme, Jordan Polovina
# 1                                                                                                                                                                  Ablaze, Clinton Sly, Herobust, Zempra
# 2                                                                                                                                                               Adventure Club, Smokestax, Purge, Dyatic
# 3                                                                                                                                                             Kursa, Fuski, Drakk, Robotic Pirate Monkey
# 4                                                                                                                                                      Magnolia North, Steve Foltz, Liver Down The River
# 5                                                                                                    Wookiefoot, Mike Love, Yak Attack, Analog Son, A-Mac & The Height, Graham Good & The Painters, &, -
# 6                                                                                                                                                       Neetesh Jung Kunwar & Bartika Eam, Jaanvi Gurung
# 7                                                                             Porter Neville Quartet, George Porter Jr, Ivan Neville, Ian Neville, Terrence Houston, JoeBaby All-Star Jam, Jermal Watson
# 8                  Maydaze Music Fest, Stay Gypsy, Adamsite, Paradox, Feens!, Nothing's Permanent, Ain't From Here, Sunny Sideways, The Cereal Company, Stereo Indica Cinema, Messenger Music Collective
# 9                                                                                                                                                                   The Elovaters, CollieRAD, MountainUs
# 10                                                            The Funk Sessions, Isaac Teel, Marc Brownstein, The, Jennifer, Nick, The, Joey Porter, The, Nicholas Gerlach, The, D-Vibes Watermelon Funk
# 11                                                                                                                                           Dynohunter, Casual Commander, Aaron Bordas, Jordan Polovina
# 12                                                                                                                                                Bloodkin, Daniella Katzir Band, Band, Big Time Rascals
# 13                                                                                                                                                          Upstate, Emma Mayes & The Hip, Plain Faraday
# 14                                                                                                                                  Xavier Wulf, Beau Young Prince, Marty Grimes, Reco Havoc, Indigo Ace
# 15                                                                                                                                                  Morphics, Dirty Audio, Tokey, Reco Havoc, Indigo Ace
# 16                                                                            The Family Peach, Vaylor Trucks, Trucks, Jeff Franca, Todd Smallie, James Dumm, Bill McKay, Eric Sanders, Coral Creek, The
# 17  Anomalous, Truth, Doc Suess & Lakhryth, Sensei3Moons, Nuclear Ninja, Bby Backwood, BMW Records BB, TRiP, JR Tycoon, Talisa, Buggabearmaxie, Atlus, KINGPEN KEN, 187 klaN, Getti, Gadgio, Fuego James
# 18  Anomalous, Truth, Doc Suess & Lakhryth, Sensei3Moons, Nuclear Ninja, Bby Backwood, BMW Records BB, TRiP, JR Tycoon, Talisa, Buggabearmaxie, Atlus, KINGPEN KEN, 187 klaN, Getti, Gadgio, Fuego James
# 19                                                                                                                                        Homemade Spaceship, Pigeon Hole, Kyral, Banko, Jordan Polovina
# 20                                                                                                                                                        iLL Gates, Ghostz, Riot x Ten, Jordan Polovina
# 21                                                                                                                                                               Holly, Space Laces, Kill x Will, Snacks
# 22                                                                                                                                                        Kadaver, Cookie Monsta, Prob x Cause, Teminite
# 23                                                                                              Coral Creek, Drew Emmitt, Todd Sheaffer, Todd Sheaffer Solo Set, Creek, Coral Creek, Mary-Elaine Jenkins
# 24                                                                                                                       Hieroglyphics, Rap Noir, Stoney Hawk, S.A.V.E.1, Mike Wird, L0S, Stonewall BLVD
# 25                                                                                                            Scott Law & Ross James Cosmic Twang, Nicki Bluhm, Keith Moseley, & Alex Koford, The Higgs
# 26                                                                                                                                                            Tor, Andrew Rothschild, Moon Frog Band, To
# 27                                                                                                                                                                                            NLE Choppa
# 28                                                                                                                                                 C.H.A.Y., Kyle Walker, Andy Immerman, Jordan Polovina
# 29                                                                                                                      Circus No. 9, Fireside Collective, Bunch Of Strangers, & Beer Festival Pre-Party
# ..                                                                                                                                                                                                   ...
# 62                                                                                                                                                                  Hymn For Her, The Deer, Che Apalache
# 63                                                                                                                                                                    Lost Dog Street Band, Matt Heckler
# 64                                                                                                                                                                          Butcher Brown, Dirty Revival
# 65                                                                                                                                                                                   Dobre Brothers Live
# 66                                                                                                                                                                        Defunk, Memba, Jordan Polovina
# 67                                                                                                                                                      Jay Cobb Anderson Band, Nirvana's Unplugged, and
# 68
# 69                                                                                                                                          Nolatet, Mike Dillon, Brian Haas, and James Singleton, Dandu
# 70                                                                                                                                       Ultrasloth, Duffrey, BioLumigen, kLL sMTH, 5AM, Jordan Polovina
# 71                                                                                                                                                                Tristam, Griz, Leau, Jason, Born, DMVU
# 72                                                                                                                                                Lord Swan, Blanke, Louis Futon, Eprom, Vanic, Audiowrx
# 73                                                                                                                                                Jampact, Major Lazer, Ratchet, Kenno, 1788, Jason Ross
# 74                                                                                                                                                                           The Billy Failing Band, The
# 75                                                                                                                                                                                  STS9 Wave Spell Live
# 76                                                                                                                                                                     40 Oz To Freedom, Lil' Ween, Ween
# 77
# 78
# 79                                                                                                                                                             The Geek x VRV, Poldoore, Jordan Polovina
# 80                                                                                                                                                                      The New Mastersounds, Ghost-Note
# 81                                                                                                                                                                      The New Mastersounds, Ghost-Note
# 82                                                                                                                                                                              The Game Show, Game Show
# 83                                                                                                                                                    Wu-Tang Clan, Jedi Mind Tricks, Immortal Technique
# 84                                                                                                                                                                            An Evening With That 1 Guy
# 85                                                                                                                                                                           Hilltop Hoods, Adrian Eagle
# 86                                                                                                                                                                    Disco, Floopy, Drippy, Ants, tacos
# 87                                                                                                                                                    Danky, Popcorn, Zeds Dead, Louis the Child, shrimp
# 88                                                                                                                                                                                          I Make Music
# 89                                                                                                                                                                   Advice With Him, The Bike, kLL sMTH
# 90                                                                                                                                                                               Fire & Ice, Heem Banana
# 91                                                                                                                                                           Stylust, Shrimp Taco, CharlestheFirst, ZLEN
#
# [92 rows x 2 columns]

# %%
tagger.dump(filename='stdout')
